# %%
# %%writefile module_mymath_01.py
mypi = 3.14

def add(a, b) : 
    return a + b

def area(r) :
    return mypi * (r ** 2)
# Out:
# Writing module_mymath_01.py

# %%
import module_mymath_01

# print(dir(module_mymath_01))

print(module_mymath_01.mypi)
print(module_mymath_01.area(5))
# Out:
# 3.14
# 78.5

# %%
from module_mymath_01 import mypi, add, area

print(mypi)
# Out:
# 3.14

# %%
import module_mymath_01 as mm

# print(dir(module_mymath_01))

print(mm.mypi)
print(mm.area(5))
# Out:
# 3.14
# 78.5

# %%
import math

print(math.__name__)
# Out:
# math

# %%
# %%writefile module_prname.py

print(__name__)
# Out:
# Overwriting module_prname.py

# %%
# !uv run module_prname.py
# !python module_prname.py
# Out:
# __main__

# %%
# %%writefile main2.py
import sys
sys.path.append(r"C:\skn35\workspace\uv-py-workspace")
import my_shapes. area as ma

print(ma.circle_area(5))
# Out:
# 78.5

# %%
import os
print(os.getcwd())
# Out:
# c:\skn35\workspace\uv-py-workspace\day6
